# %% [markdown]
# ## Import Libraries

# %%
import os
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
import seaborn as sns
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import LSTM, Dense, Conv2D, TimeDistributed, Flatten, GRU, Dropout, MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
# Enable memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# Enable mixed precision
from tensorflow.keras import mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060, compute capability 8.6

# %% [markdown]
# ### Convert Raw video datasets into a 320x240 at 30fps

# %%
def downgrade_video_quality(input_folder, output_folder, target_width=320, target_height=240, target_fps=30):
    """
    Downgrades the quality of videos in a given folder and organizes them by exercise name.

    Args:
        input_folder: The path to the folder containing the raw videos.
        output_folder: The path to the folder where the downgraded videos will be saved.
        target_width: The desired width of the output videos.
        target_height: The desired height of the output videos.
        target_fps:  The desired frames per second.  Crucially, get from the original.
    """

    # Create the output folder and subfolders if they don't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for exercise_name in os.listdir(input_folder):
        exercise_path = os.path.join(input_folder, exercise_name)

        # Check if it's a directory (to avoid processing non-directory files)
        if os.path.isdir(exercise_path):
            output_exercise_path = os.path.join(output_folder, exercise_name)
            if not os.path.exists(output_exercise_path):
                os.makedirs(output_exercise_path)

            for filename in os.listdir(exercise_path):
                if filename.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):  # Add more extensions if needed
                    input_filepath = os.path.join(exercise_path, filename)
                    output_filepath = os.path.join(output_exercise_path, filename)

                    try:
                        # Open the video file
                        video_capture = cv2.VideoCapture(input_filepath)

                        # Check if video opened successfully
                        if not video_capture.isOpened():
                            print(f"Error: Could not open video {input_filepath}")
                            continue

                        # Get original video properties
                        original_fps = video_capture.get(cv2.CAP_PROP_FPS)
                        # original_width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH)) #Not used
                        # original_height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT)) #Not used
                        
                        # Use the original FPS if target_fps is not specified or is invalid
                        fps_to_use = original_fps if original_fps > 0 else target_fps

                        # Define the codec and create VideoWriter object
                        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'XVID' for AVI, or other codecs as needed
                        out = cv2.VideoWriter(output_filepath, fourcc, fps_to_use, (target_width, target_height))


                        while True:
                            ret, frame = video_capture.read()
                            if not ret:
                                break  # End of video

                            # Resize the frame
                            resized_frame = cv2.resize(frame, (target_width, target_height))

                            # Write the resized frame to the output video
                            out.write(resized_frame)

                        # Release resources
                        video_capture.release()
                        out.release()
                        print(f"Processed: {input_filepath} -> {output_filepath}")

                    except Exception as e:
                        print(f"Error processing {input_filepath}: {e}")

    print("Video processing complete.")

if __name__ == '__main__':
    raw_folder = "raw"  # Replace with the actual path to your raw videos folder
    downgraded_folder = "downgraded_raw"  # The output folder

    downgrade_video_quality(raw_folder, downgraded_folder)
# Out:
# Processed: raw\LumbarSideBends\1.mp4 -> downgraded_raw\LumbarSideBends\1.mp4
# Processed: raw\LumbarSideBends\13631965-3410-4313-9a12-faa683b44961.mp4 -> downgraded_raw\LumbarSideBends\13631965-3410-4313-9a12-faa683b44961.mp4
# Processed: raw\LumbarSideBends\2 2.mp4 -> downgraded_raw\LumbarSideBends\2 2.mp4
# Processed: raw\LumbarSideBends\2.mp4 -> downgraded_raw\LumbarSideBends\2.mp4
# Processed: raw\LumbarSideBends\20250205_053352000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250205_053352000_iOS.MOV
# Processed: raw\LumbarSideBends\20250205_053735000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250205_053735000_iOS.MOV
# Processed: raw\LumbarSideBends\20250206_063412000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250206_063412000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_065855000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_065855000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_070410000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_070410000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_085332000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_085332000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_085450000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_085450000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_085544000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_085544000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_085743000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_085743000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090205000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090205000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090331000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090331000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090433000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090433000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090537000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090537000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090718000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090718000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090837000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090837000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_090932000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_090932000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_091023000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_091023000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_091430000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_091430000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_091718000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_091718000_iOS.MOV
# Processed: raw\LumbarSideBends\20250223_091836000_iOS.MOV -> downgraded_raw\LumbarSideBends\20250223_091836000_iOS.MOV
# Processed: raw\LumbarSideBends\2a4b91c5-d862-4e91-820e-d51c7eeeadbf.mp4 -> downgraded_raw\LumbarSideBends\2a4b91c5-d862-4e91-820e-d51c7eeeadbf.mp4
# Processed: raw\LumbarSideBends\3.mp4 -> downgraded_raw\LumbarSideBends\3.mp4
# Processed: raw\LumbarSideBends\4377a7de-0af4-40ef-a30e-4dff56cdb0f9.mp4 -> downgraded_raw\LumbarSideBends\4377a7de-0af4-40ef-a30e-4dff56cdb0f9.mp4
# Processed: raw\LumbarSideBends\475555509_9263473073698401_6919277742428364951_n.mp4 -> downgraded_raw\LumbarSideBends\475555509_9263473073698401_6919277742428364951_n.mp4
# Processed: raw\LumbarSideBends\475871883_9236836983060007_880998261948400557_n (1).mp4 -> downgraded_raw\LumbarSideBends\475871883_9236836983060007_880998261948400557_n (1).mp4
# Processed: raw\LumbarSideBends\475874828_9483337038357444_2782041067290051443_n (1).mp4 -> downgraded_raw\LumbarSideBends\475874828_9483337038357444_2782041067290051443_n (1).mp4
# Processed: raw\LumbarSideBends\475966540_9252106844868311_3579406190886816435_n.mp4 -> downgraded_raw\LumbarSideBends\475966540_9252106844868311_3579406190886816435_n.mp4
# Processed: raw\LumbarSideBends\476175041_9469987729718233_282338069795470620_n.mp4 -> downgraded_raw\LumbarSideBends\476175041_9469987729718233_282338069795470620_n.mp4
# Processed: raw\LumbarSideBends\476283350_28540709152211411_5647428866378279748_n.mp4 -> downgraded_raw\LumbarSideBends\476283350_28540709152211411_5647428866378279748_n.mp4
# Processed: raw\LumbarSideBends\476292852_8853409808118156_7318122711209303880_n.mp4 -> downgraded_raw\LumbarSideBends\476292852_8853409808118156_7318122711209303880_n.mp4
# Processed: raw\LumbarSideBends\476353066_24090027447264294_4002421869367492500_n.mp4 -> downgraded_raw\LumbarSideBends\476353066_24090027447264294_4002421869367492500_n.mp4
# Processed: raw\LumbarSideBends\476448759_9583300931681870_8295200281388544956_n.mp4 -> downgraded_raw\LumbarSideBends\476448759_9583300931681870_8295200281388544956_n.mp4
# Processed: raw\LumbarSideBends\476452355_9632028876816500_2639251741226122349_n.mp4 -> downgraded_raw\LumbarSideBends\476452355_9632028876816500_2639251741226122349_n.mp4
# Processed: raw\LumbarSideBends\476531988_28418094074501969_8705003528007450697_n.mp4 -> downgraded_raw\LumbarSideBends\476531988_28418094074501969_8705003528007450697_n.mp4
# Processed: raw\LumbarSideBends\476590151_9544519045592873_5101180632781136893_n.mp4 -> downgraded_raw\LumbarSideBends\476590151_9544519045592873_5101180632781136893_n.mp4
# Processed: raw\LumbarSideBends\476626781_9170016793114494_2003711044015465750_n.mp4 -> downgraded_raw\LumbarSideBends\476626781_9170016793114494_2003711044015465750_n.mp4
# Processed: raw\LumbarSideBends\476728088_28456418770639675_5469483570780241191_n.mp4 -> downgraded_raw\LumbarSideBends\476728088_28456418770639675_5469483570780241191_n.mp4
# Processed: raw\LumbarSideBends\476750181_28576008268711782_268436605633700656_n.mp4 -> downgraded_raw\LumbarSideBends\476750181_28576008268711782_268436605633700656_n.mp4
# Processed: raw\LumbarSideBends\476763089_9687444591266200_5348226696328856097_n.mp4 -> downgraded_raw\LumbarSideBends\476763089_9687444591266200_5348226696328856097_n.mp4
# Processed: raw\LumbarSideBends\476763928_29316826131249981_8195095401457948521_n.mp4 -> downgraded_raw\LumbarSideBends\476763928_29316826131249981_8195095401457948521_n.mp4
# Processed: raw\LumbarSideBends\476820660_28830756913182079_1043620940347656278_n.mp4 -> downgraded_raw\LumbarSideBends\476820660_28830756913182079_1043620940347656278_n.mp4
# Processed: raw\LumbarSideBends\476840848_9676740822365438_3042886991144378692_n.mp4 -> downgraded_raw\LumbarSideBends\476840848_9676740822365438_3042886991144378692_n.mp4
# Processed: raw\LumbarSideBends\476909506_7873808712744286_420104182016391536_n.mp4 -> downgraded_raw\LumbarSideBends\476909506_7873808712744286_420104182016391536_n.mp4
# Processed: raw\LumbarSideBends\476910945_9474244712607564_3382838545258464235_n.mp4 -> downgraded_raw\LumbarSideBends\476910945_9474244712607564_3382838545258464235_n.mp4
# Processed: raw\LumbarSideBends\477200363_9132650726816308_6475971801651834471_n.mp4 -> downgraded_raw\LumbarSideBends\477200363_9132650726816308_6475971801651834471_n.mp4
# Processed: raw\LumbarSideBends\477765538_28878233501767907_1010693419866071539_n.mp4 -> downgraded_raw\LumbarSideBends\477765538_28878233501767907_1010693419866071539_n.mp4
# Processed: raw\LumbarSideBends\480973482_9502929709763781_1998267846929441597_n.mp4 -> downgraded_raw\LumbarSideBends\480973482_9502929709763781_1998267846929441597_n.mp4
# Processed: raw\LumbarSideBends\5.mp4 -> downgraded_raw\LumbarSideBends\5.mp4
# Processed: raw\LumbarSideBends\6.mp4 -> downgraded_raw\LumbarSideBends\6.mp4
# Processed: raw\LumbarSideBends\7.mp4 -> downgraded_raw\LumbarSideBends\7.mp4
# Processed: raw\LumbarSideBends\8.mp4 -> downgraded_raw\LumbarSideBends\8.mp4
# Processed: raw\LumbarSideBends\a357f4b1-9ffd-4a83-8f28-743aaee7cd64.mp4 -> downgraded_raw\LumbarSideBends\a357f4b1-9ffd-4a83-8f28-743aaee7cd64.mp4
# Processed: raw\LumbarSideBends\b7495c16-d4f5-49c6-aa3d-e7de8fc790fa.mp4 -> downgraded_raw\LumbarSideBends\b7495c16-d4f5-49c6-aa3d-e7de8fc790fa.mp4
# Processed: raw\LumbarSideBends\f18f166d-db07-4ee6-a322-43236014d519.mp4 -> downgraded_raw\LumbarSideBends\f18f166d-db07-4ee6-a322-43236014d519.mp4
# Processed: raw\LumbarSideBends\IMG_2355.mp4 -> downgraded_raw\LumbarSideBends\IMG_2355.mp4
# Processed: raw\LumbarSideBends\IMG_2360.mp4 -> downgraded_raw\LumbarSideBends\IMG_2360.mp4
# Processed: raw\LumbarSideBends\inbound1469095937523786000.mp4 -> downgraded_raw\LumbarSideBends\inbound1469095937523786000.mp4
# Processed: raw\LumbarSideBends\inbound1818732822578510857.mp4 -> downgraded_raw\LumbarSideBends\inbound1818732822578510857.mp4
# Processed: raw\LumbarSideBends\inbound3301684621817025250.mp4 -> downgraded_raw\LumbarSideBends\inbound3301684621817025250.mp4
# Processed: raw\LumbarSideBends\inbound7355810723406652564.mp4 -> downgraded_raw\LumbarSideBends\inbound7355810723406652564.mp4
# Processed: raw\LumbarSideBends\inbound8397842841126244516.mp4 -> downgraded_raw\LumbarSideBends\inbound8397842841126244516.mp4
# Processed: raw\LumbarSideBends\inbound8622408709054191758.mp4 -> downgraded_raw\LumbarSideBends\inbound8622408709054191758.mp4
# Processed: raw\LumbarSideBends\LSB_1.mp4 -> downgraded_raw\LumbarSideBends\LSB_1.mp4
# Processed: raw\LumbarSideBends\LSB_2.mp4 -> downgraded_raw\LumbarSideBends\LSB_2.mp4
# Processed: raw\LumbarSideBends\LSB_3.mp4 -> downgraded_raw\LumbarSideBends\LSB_3.mp4
# Processed: raw\LumbarSideBends\LSB_4.mp4 -> downgraded_raw\LumbarSideBends\LSB_4.mp4
# Processed: raw\LumbarSideBends\LSB_5.mp4 -> downgraded_raw\LumbarSideBends\LSB_5.mp4
# Processed: raw\LumbarSideBends\LSB_6.mp4 -> downgraded_raw\LumbarSideBends\LSB_6.mp4
# Processed: raw\LumbarSideBends\VID_20240128_150039.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_150039.mp4
# Processed: raw\LumbarSideBends\VID_20240128_154856.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_154856.mp4
# Processed: raw\LumbarSideBends\VID_20240128_155510.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_155510.mp4
# Processed: raw\LumbarSideBends\VID_20240128_155904.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_155904.mp4
# Processed: raw\LumbarSideBends\VID_20240128_155929.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_155929.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171001.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171001.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171020.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171020.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171042.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171042.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171110.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171110.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171146.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171146.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171255.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171255.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171321.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171321.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171435.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171435.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171454.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171454.mp4
# Processed: raw\LumbarSideBends\VID_20240128_171901.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_171901.mp4
# Processed: raw\LumbarSideBends\VID_20240128_172043.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_172043.mp4
# Processed: raw\LumbarSideBends\VID_20240128_172336.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_172336.mp4
# Processed: raw\LumbarSideBends\VID_20240128_172425.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_172425.mp4
# Processed: raw\LumbarSideBends\VID_20240128_172442.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_172442.mp4
# Processed: raw\LumbarSideBends\VID_20240128_172519.mp4 -> downgraded_raw\LumbarSideBends\VID_20240128_172519.mp4
# Processed: raw\LumbarSideBends\VID_20250223_011651.mp4 -> downgraded_raw\LumbarSideBends\VID_20250223_011651.mp4
# Processed: raw\LumbarSideBends\VID_20250223_011734.mp4 -> downgraded_raw\LumbarSideBends\VID_20250223_011734.mp4
# Processed: raw\LumbarSideBends\VID_20250223_012557.mp4 -> downgraded_raw\LumbarSideBends\VID_20250223_012557.mp4
# Processed: raw\LumbarSideBends\VID_20250223_012637.mp4 -> downgraded_raw\LumbarSideBends\VID_20250223_012637.mp4
# Processed: raw\QuadrupedThoracicRotation\02a7b6cd-7675-46f5-8ad9-f710e9fe410b.mp4 -> downgraded_raw\QuadrupedThoracicRotation\02a7b6cd-7675-46f5-8ad9-f710e9fe410b.mp4
# Processed: raw\QuadrupedThoracicRotation\1.mp4 -> downgraded_raw\QuadrupedThoracicRotation\1.mp4
# Processed: raw\QuadrupedThoracicRotation\2.mp4 -> downgraded_raw\QuadrupedThoracicRotation\2.mp4
# Processed: raw\QuadrupedThoracicRotation\20250205_053331000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250205_053331000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250205_053709000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250205_053709000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250205_053808000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250205_053808000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250206_063347000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250206_063347000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_070025000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_070025000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_070501000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_070501000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_085354000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_085354000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_085434000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_085434000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_085632000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_085632000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_085721000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_085721000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090226000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090226000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090312000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090312000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090445000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090445000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090523000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090523000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090750000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090750000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090821000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090821000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_090944000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_090944000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_091035000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_091035000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_091446000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_091446000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_091626000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_091626000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_091735000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_091735000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\20250223_091819000_iOS.MOV -> downgraded_raw\QuadrupedThoracicRotation\20250223_091819000_iOS.MOV
# Processed: raw\QuadrupedThoracicRotation\2901c6df-1823-4f02-80c8-e62cee29139e.mp4 -> downgraded_raw\QuadrupedThoracicRotation\2901c6df-1823-4f02-80c8-e62cee29139e.mp4
# Processed: raw\QuadrupedThoracicRotation\3.mp4 -> downgraded_raw\QuadrupedThoracicRotation\3.mp4
# Processed: raw\QuadrupedThoracicRotation\4 2.mp4 -> downgraded_raw\QuadrupedThoracicRotation\4 2.mp4
# Processed: raw\QuadrupedThoracicRotation\4.mp4 -> downgraded_raw\QuadrupedThoracicRotation\4.mp4
# Processed: raw\QuadrupedThoracicRotation\475573777_29350569564542178_6173402059368208791_n (1).mp4 -> downgraded_raw\QuadrupedThoracicRotation\475573777_29350569564542178_6173402059368208791_n (1).mp4
# Processed: raw\QuadrupedThoracicRotation\475931645_9934694636559708_2247362719048479617_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\475931645_9934694636559708_2247362719048479617_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476020382_8942004155897487_2510035997423911799_n (1).mp4 -> downgraded_raw\QuadrupedThoracicRotation\476020382_8942004155897487_2510035997423911799_n (1).mp4
# Processed: raw\QuadrupedThoracicRotation\476021627_9586399654717125_6448562608570335755_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476021627_9586399654717125_6448562608570335755_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476275889_9178449908897527_230538083594954735_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476275889_9178449908897527_230538083594954735_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476320495_1996101550899307_7414120751304269736_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476320495_1996101550899307_7414120751304269736_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476369468_9074480742599916_2253501664638776712_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476369468_9074480742599916_2253501664638776712_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476424566_8945590785566578_463272045710938220_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476424566_8945590785566578_463272045710938220_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476444375_29125736163680195_4295701615655092125_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476444375_29125736163680195_4295701615655092125_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476499650_9240531072707258_2799125233244944016_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476499650_9240531072707258_2799125233244944016_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476560177_9407029976021784_7401468772860817634_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476560177_9407029976021784_7401468772860817634_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476618837_29025155000409142_6193472846688749488_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476618837_29025155000409142_6193472846688749488_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476627116_9244291025662884_5393452660399882111_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476627116_9244291025662884_5393452660399882111_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476627928_29352220654368817_4303074011572626026_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476627928_29352220654368817_4303074011572626026_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476630325_9095831093869287_517665879117883568_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476630325_9095831093869287_517665879117883568_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476632274_9056173314470162_2846799382995953308_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476632274_9056173314470162_2846799382995953308_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476644085_9352454071441360_8664239234719222274_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476644085_9352454071441360_8664239234719222274_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476644115_9068900966535572_6785925640125531332_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476644115_9068900966535572_6785925640125531332_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476663852_9613889481964043_5380896427762418051_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476663852_9613889481964043_5380896427762418051_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476779091_9377600992278224_3944754560654918062_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476779091_9377600992278224_3944754560654918062_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476888525_28731099939869142_6941365423819108546_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476888525_28731099939869142_6941365423819108546_n.mp4
# Processed: raw\QuadrupedThoracicRotation\476910722_28922036047387800_6434644836439361383_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\476910722_28922036047387800_6434644836439361383_n.mp4
# Processed: raw\QuadrupedThoracicRotation\477111168_29029871419944722_6253338098103194984_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\477111168_29029871419944722_6253338098103194984_n.mp4
# Processed: raw\QuadrupedThoracicRotation\480847125_9138538152868144_2625008535774746045_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\480847125_9138538152868144_2625008535774746045_n.mp4
# Processed: raw\QuadrupedThoracicRotation\480900224_9579905128768700_8399079993598580002_n.mp4 -> downgraded_raw\QuadrupedThoracicRotation\480900224_9579905128768700_8399079993598580002_n.mp4
# Processed: raw\QuadrupedThoracicRotation\5.mp4 -> downgraded_raw\QuadrupedThoracicRotation\5.mp4
# Processed: raw\QuadrupedThoracicRotation\6124ad36-a129-4ca9-a7ce-387b1cbf4e05.mp4 -> downgraded_raw\QuadrupedThoracicRotation\6124ad36-a129-4ca9-a7ce-387b1cbf4e05.mp4
# Processed: raw\QuadrupedThoracicRotation\ec2ae1b6-2601-486b-bdb6-eb370d216af2.mp4 -> downgraded_raw\QuadrupedThoracicRotation\ec2ae1b6-2601-486b-bdb6-eb370d216af2.mp4
# Processed: raw\QuadrupedThoracicRotation\f710a653-762b-42a6-a05e-56cab3ebdf0a.mp4 -> downgraded_raw\QuadrupedThoracicRotation\f710a653-762b-42a6-a05e-56cab3ebdf0a.mp4
# Processed: raw\QuadrupedThoracicRotation\IMG_2357.mp4 -> downgraded_raw\QuadrupedThoracicRotation\IMG_2357.mp4
# Processed: raw\QuadrupedThoracicRotation\IMG_2359.mov -> downgraded_raw\QuadrupedThoracicRotation\IMG_2359.mov
# Processed: raw\QuadrupedThoracicRotation\inbound1406552046754842695.mp4 -> downgraded_raw\QuadrupedThoracicRotation\inbound1406552046754842695.mp4
# Processed: raw\QuadrupedThoracicRotation\inbound1976048177900984497.mp4 -> downgraded_raw\QuadrupedThoracicRotation\inbound1976048177900984497.mp4
# Processed: raw\QuadrupedThoracicRotation\inbound2178649348277160754.mp4 -> downgraded_raw\QuadrupedThoracicRotation\inbound2178649348277160754.mp4
# Processed: raw\QuadrupedThoracicRotation\inbound2611768600744359994.mp4 -> downgraded_raw\QuadrupedThoracicRotation\inbound2611768600744359994.mp4
# Processed: raw\QuadrupedThoracicRotation\inbound5925177570514424382.mp4 -> downgraded_raw\QuadrupedThoracicRotation\inbound5925177570514424382.mp4
# Processed: raw\QuadrupedThoracicRotation\inbound6731374140114374085.mp4 -> downgraded_raw\QuadrupedThoracicRotation\inbound6731374140114374085.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_1.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_1.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_2.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_2.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_3.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_3.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_4.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_4.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_5.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_5.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_6.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_6.mp4
# Processed: raw\QuadrupedThoracicRotation\QTR_7.mp4 -> downgraded_raw\QuadrupedThoracicRotation\QTR_7.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153016.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153016.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153032.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153032.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153047.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153047.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153526.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153526.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153545.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153545.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153811.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153811.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_153826.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_153826.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_164354.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_164354.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_164633.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_164633.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_164732.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_164732.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_164747.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_164747.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_164801.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_164801.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_165208.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_165208.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_165237.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_165237.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_165602.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_165602.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_173938.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_173938.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_174000.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_174000.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_174527.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_174527.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_174542.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_174542.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20240128_174556.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20240128_174556.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20250223_010917.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20250223_010917.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20250223_011001.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20250223_011001.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20250223_013146.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20250223_013146.mp4
# Processed: raw\QuadrupedThoracicRotation\VID_20250223_013240.mp4 -> downgraded_raw\QuadrupedThoracicRotation\VID_20250223_013240.mp4
# Processed: raw\SupineNeckLift\015614b5-3d6e-4c11-b388-76a22af27145.mp4 -> downgraded_raw\SupineNeckLift\015614b5-3d6e-4c11-b388-76a22af27145.mp4
# Processed: raw\SupineNeckLift\158b38c3-6152-4af0-a129-a0cfbff557fb.mp4 -> downgraded_raw\SupineNeckLift\158b38c3-6152-4af0-a129-a0cfbff557fb.mp4
# Processed: raw\SupineNeckLift\2.mp4 -> downgraded_raw\SupineNeckLift\2.mp4
# Processed: raw\SupineNeckLift\20250205_053313000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250205_053313000_iOS.MOV
# Processed: raw\SupineNeckLift\20250205_053753000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250205_053753000_iOS.MOV
# Processed: raw\SupineNeckLift\20250206_063305000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250206_063305000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_070131000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_070131000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_070556000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_070556000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_085257000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_085257000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_085505000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_085505000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_085615000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_085615000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_085757000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_085757000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090138000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090138000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090349000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090349000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090418000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090418000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090551000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090551000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090703000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090703000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090851000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090851000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_090919000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_090919000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_091010000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_091010000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_091407000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_091407000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_091606000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_091606000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_091657000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_091657000_iOS.MOV
# Processed: raw\SupineNeckLift\20250223_091859000_iOS.MOV -> downgraded_raw\SupineNeckLift\20250223_091859000_iOS.MOV
# Processed: raw\SupineNeckLift\4.mp4 -> downgraded_raw\SupineNeckLift\4.mp4
# Processed: raw\SupineNeckLift\476078471_847307494132236_149117734707404079_n (1).mp4 -> downgraded_raw\SupineNeckLift\476078471_847307494132236_149117734707404079_n (1).mp4
# Processed: raw\SupineNeckLift\476146715_8813457945443601_3172673603932919834_n.mp4 -> downgraded_raw\SupineNeckLift\476146715_8813457945443601_3172673603932919834_n.mp4
# Processed: raw\SupineNeckLift\476210947_9157144487732794_4707249798001650183_n.mp4 -> downgraded_raw\SupineNeckLift\476210947_9157144487732794_4707249798001650183_n.mp4
# Processed: raw\SupineNeckLift\476239346_9510914505593449_3230902881945318027_n.mp4 -> downgraded_raw\SupineNeckLift\476239346_9510914505593449_3230902881945318027_n.mp4
# Processed: raw\SupineNeckLift\476287386_9682243671809104_4097647272972193283_n.mp4 -> downgraded_raw\SupineNeckLift\476287386_9682243671809104_4097647272972193283_n.mp4
# Processed: raw\SupineNeckLift\476309969_9180668195380872_2799235701195585664_n.mp4 -> downgraded_raw\SupineNeckLift\476309969_9180668195380872_2799235701195585664_n.mp4
# Processed: raw\SupineNeckLift\476329255_9422820991116007_2974791422362375177_n.mp4 -> downgraded_raw\SupineNeckLift\476329255_9422820991116007_2974791422362375177_n.mp4
# Processed: raw\SupineNeckLift\476374195_9051326688284458_1722831520852107909_n.mp4 -> downgraded_raw\SupineNeckLift\476374195_9051326688284458_1722831520852107909_n.mp4
# Processed: raw\SupineNeckLift\476417864_9017961084925079_1955037045460743369_n.mp4 -> downgraded_raw\SupineNeckLift\476417864_9017961084925079_1955037045460743369_n.mp4
# Processed: raw\SupineNeckLift\476442901_9706608736019006_3551577948367103466_n.mp4 -> downgraded_raw\SupineNeckLift\476442901_9706608736019006_3551577948367103466_n.mp4
# Processed: raw\SupineNeckLift\476458453_8977858295644746_4226371830824299332_n.mp4 -> downgraded_raw\SupineNeckLift\476458453_8977858295644746_4226371830824299332_n.mp4
# Processed: raw\SupineNeckLift\476562524_8943821759073248_4166721590785628637_n.mp4 -> downgraded_raw\SupineNeckLift\476562524_8943821759073248_4166721590785628637_n.mp4
# Processed: raw\SupineNeckLift\476580192_9076626509100584_4894695565268021897_n.mp4 -> downgraded_raw\SupineNeckLift\476580192_9076626509100584_4894695565268021897_n.mp4
# Processed: raw\SupineNeckLift\476617850_8919039601555756_7959366714030196406_n.mp4 -> downgraded_raw\SupineNeckLift\476617850_8919039601555756_7959366714030196406_n.mp4
# Processed: raw\SupineNeckLift\476629440_9324525574262193_3019487839729914388_n.mp4 -> downgraded_raw\SupineNeckLift\476629440_9324525574262193_3019487839729914388_n.mp4
# Processed: raw\SupineNeckLift\476644971_28636457786001241_7994662531031862474_n.mp4 -> downgraded_raw\SupineNeckLift\476644971_28636457786001241_7994662531031862474_n.mp4
# Processed: raw\SupineNeckLift\476648780_28390779537203905_8499157160923901058_n.mp4 -> downgraded_raw\SupineNeckLift\476648780_28390779537203905_8499157160923901058_n.mp4
# Processed: raw\SupineNeckLift\476655126_28531236023191367_5649046272276273505_n.mp4 -> downgraded_raw\SupineNeckLift\476655126_28531236023191367_5649046272276273505_n.mp4
# Processed: raw\SupineNeckLift\476893779_9071097169611371_7709790790586685055_n.mp4 -> downgraded_raw\SupineNeckLift\476893779_9071097169611371_7709790790586685055_n.mp4
# Processed: raw\SupineNeckLift\476920318_9274395679323720_4495487373780826843_n.mp4 -> downgraded_raw\SupineNeckLift\476920318_9274395679323720_4495487373780826843_n.mp4
# Processed: raw\SupineNeckLift\477127503_9382773781744512_903144630391749028_n.mp4 -> downgraded_raw\SupineNeckLift\477127503_9382773781744512_903144630391749028_n.mp4
# Processed: raw\SupineNeckLift\480737175_9721551291197977_5083881103263901986_n.mp4 -> downgraded_raw\SupineNeckLift\480737175_9721551291197977_5083881103263901986_n.mp4
# Processed: raw\SupineNeckLift\481095269_9418290504955516_5183511196793906464_n.mp4 -> downgraded_raw\SupineNeckLift\481095269_9418290504955516_5183511196793906464_n.mp4
# Processed: raw\SupineNeckLift\5.mp4 -> downgraded_raw\SupineNeckLift\5.mp4
# Processed: raw\SupineNeckLift\6.mp4 -> downgraded_raw\SupineNeckLift\6.mp4
# Processed: raw\SupineNeckLift\6d91d4dc-b388-4114-b119-09ad20a6d4c2.mp4 -> downgraded_raw\SupineNeckLift\6d91d4dc-b388-4114-b119-09ad20a6d4c2.mp4
# Processed: raw\SupineNeckLift\7.mp4 -> downgraded_raw\SupineNeckLift\7.mp4
# Processed: raw\SupineNeckLift\9125dd3e-db1d-4714-aa88-7b579da7949b.mp4 -> downgraded_raw\SupineNeckLift\9125dd3e-db1d-4714-aa88-7b579da7949b.mp4
# Processed: raw\SupineNeckLift\a.mp4 -> downgraded_raw\SupineNeckLift\a.mp4
# Processed: raw\SupineNeckLift\a1207c5c-a229-4d03-bd9a-6d69f13771d7.mov -> downgraded_raw\SupineNeckLift\a1207c5c-a229-4d03-bd9a-6d69f13771d7.mov
# Processed: raw\SupineNeckLift\ca8dae0a-776f-4c8e-a333-22deb75e0435.mp4 -> downgraded_raw\SupineNeckLift\ca8dae0a-776f-4c8e-a333-22deb75e0435.mp4
# Processed: raw\SupineNeckLift\IMG_0220.mov -> downgraded_raw\SupineNeckLift\IMG_0220.mov
# Processed: raw\SupineNeckLift\IMG_2356.mp4 -> downgraded_raw\SupineNeckLift\IMG_2356.mp4
# Processed: raw\SupineNeckLift\IMG_2362.mp4 -> downgraded_raw\SupineNeckLift\IMG_2362.mp4
# Processed: raw\SupineNeckLift\inbound3030395548347658845.mp4 -> downgraded_raw\SupineNeckLift\inbound3030395548347658845.mp4
# Processed: raw\SupineNeckLift\inbound3378256950004090265.mp4 -> downgraded_raw\SupineNeckLift\inbound3378256950004090265.mp4
# Processed: raw\SupineNeckLift\inbound4041289701335217324.mp4 -> downgraded_raw\SupineNeckLift\inbound4041289701335217324.mp4
# Processed: raw\SupineNeckLift\inbound5330687177508286041.mp4 -> downgraded_raw\SupineNeckLift\inbound5330687177508286041.mp4
# Processed: raw\SupineNeckLift\inbound7839587673220274997.mp4 -> downgraded_raw\SupineNeckLift\inbound7839587673220274997.mp4
# Processed: raw\SupineNeckLift\inbound933447596905727650.mp4 -> downgraded_raw\SupineNeckLift\inbound933447596905727650.mp4
# Processed: raw\SupineNeckLift\SNL_1.mp4 -> downgraded_raw\SupineNeckLift\SNL_1.mp4
# Processed: raw\SupineNeckLift\SNL_2.mp4 -> downgraded_raw\SupineNeckLift\SNL_2.mp4
# Processed: raw\SupineNeckLift\SNL_3.mp4 -> downgraded_raw\SupineNeckLift\SNL_3.mp4
# Processed: raw\SupineNeckLift\SNL_4.mp4 -> downgraded_raw\SupineNeckLift\SNL_4.mp4
# Processed: raw\SupineNeckLift\SNL_5.mp4 -> downgraded_raw\SupineNeckLift\SNL_5.mp4
# Processed: raw\SupineNeckLift\SNL_6.mp4 -> downgraded_raw\SupineNeckLift\SNL_6.mp4
# Processed: raw\SupineNeckLift\Supine Head Lifts (1).mp4 -> downgraded_raw\SupineNeckLift\Supine Head Lifts (1).mp4
# Processed: raw\SupineNeckLift\VID_20240128_151357.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_151357.mp4
# Processed: raw\SupineNeckLift\VID_20240128_151429.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_151429.mp4
# Processed: raw\SupineNeckLift\VID_20240128_151445.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_151445.mp4
# Processed: raw\SupineNeckLift\VID_20240128_151509.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_151509.mp4
# Processed: raw\SupineNeckLift\VID_20240128_151526.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_151526.mp4
# Processed: raw\SupineNeckLift\VID_20240128_151959.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_151959.mp4
# Processed: raw\SupineNeckLift\VID_20240128_152052.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_152052.mp4
# Processed: raw\SupineNeckLift\VID_20240128_152423.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_152423.mp4
# Processed: raw\SupineNeckLift\VID_20240128_152439.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_152439.mp4
# Processed: raw\SupineNeckLift\VID_20240128_152555.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_152555.mp4
# Processed: raw\SupineNeckLift\VID_20240128_152610.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_152610.mp4
# Processed: raw\SupineNeckLift\VID_20240128_162546.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_162546.mp4
# Processed: raw\SupineNeckLift\VID_20240128_162637.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_162637.mp4
# Processed: raw\SupineNeckLift\VID_20240128_162652.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_162652.mp4
# Processed: raw\SupineNeckLift\VID_20240128_163025.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_163025.mp4
# Processed: raw\SupineNeckLift\VID_20240128_163042.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_163042.mp4
# Processed: raw\SupineNeckLift\VID_20240128_173757.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_173757.mp4
# Processed: raw\SupineNeckLift\VID_20240128_174346.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_174346.mp4
# Processed: raw\SupineNeckLift\VID_20240128_174400.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_174400.mp4
# Processed: raw\SupineNeckLift\VID_20240128_174416.mp4 -> downgraded_raw\SupineNeckLift\VID_20240128_174416.mp4
# Processed: raw\SupineNeckLift\VID_20250223_010236.mp4 -> downgraded_raw\SupineNeckLift\VID_20250223_010236.mp4
# Processed: raw\SupineNeckLift\VID_20250223_010343.mp4 -> downgraded_raw\SupineNeckLift\VID_20250223_010343.mp4
# Processed: raw\SupineNeckLift\VID_20250223_012218.mp4 -> downgraded_raw\SupineNeckLift\VID_20250223_012218.mp4
# Processed: raw\SupineNeckLift\VID_20250223_012314.mp4 -> downgraded_raw\SupineNeckLift\VID_20250223_012314.mp4
# Video processing complete.

# %% [markdown]
# ### Set Numpy, Python, and TF seeds

# %%
seed_constant = 12
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

batch_size = 8 # Change this shit pag sasabog na yung GPU

# %% [markdown]
# ## Visualize Data for 1st CNN stream

# %%
plt.figure(figsize = (20,20))

all_class_names = os.listdir('downgraded_raw')

random_range = random.sample(range(len(all_class_names)), 3)

for counter, random_index in enumerate(random_range, 1):
    selected_class_name = all_class_names[random_index]

    video_files_names_list = os.listdir(f'downgraded_raw/{selected_class_name}') 
    selected_video_file_name =  random.choice(video_files_names_list)

    video_reader = cv2.VideoCapture(f'downgraded_raw/{selected_class_name}/{selected_video_file_name}')

    _, bgr_frame = video_reader.read()
    video_reader.release()

    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    cv2.putText(rgb_frame, selected_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255),1)

    plt.subplot(5,4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %% [markdown]
# ## PreProcess the Dataset

# %%
IMAGE_HEIGHT, IMAGE_WIDTH =  96, 96 #for rgb/1st stream

OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH = 224,224

SEQUENCE_LENGTH = 30

DATASET_DIR = r"D:\MAPUA\CNN_GRU_VarietyofOF\downgraded_raw"

CLASSES_LIST = ['LumbarSideBends','QuadrupedThoracicRotation','SupineNeckLift']

# %% [markdown]
# ## Extraction of Features

# %% [markdown]
# 1st Stream

# %%
def frames_extraction_RGB(video_path):
    """Extract frames from video and return normalized RGB frames"""
    frames_list1 = []
    
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / SEQUENCE_LENGTH), 1)
    
    for frame_counter in range(SEQUENCE_LENGTH):
        # Set the position of the next frame to read
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        
        success, frame = video_reader.read()
        if not success:
            break
        
        # Convert BGR (default in OpenCV) to RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Resize to target dimensions and normalize to [0, 1]
        resized_frame = cv2.resize(frame, (IMAGE_WIDTH, IMAGE_HEIGHT))
        normalized_frame = resized_frame / 255.0
        
        frames_list1.append(normalized_frame)
    
    video_reader.release()
    
    # Determine a padding frame if fewer than SEQUENCE_LENGTH frames were extracted
    if frames_list1:
        pad_frame = np.zeros_like(frames_list1[0])
    else:
        pad_frame = np.zeros((IMAGE_HEIGHT, IMAGE_WIDTH, 3), dtype=np.float32)
    
    # Pad the list to ensure the length is SEQUENCE_LENGTH
    while len(frames_list1) < SEQUENCE_LENGTH:
        frames_list1.append(pad_frame)
    
    return frames_list1

# %% [markdown]
# 2nd CNN Stream

# %% [markdown]
# ###### Get optical flow frames

# %%
def compute_optical_flow(prev_frame, next_frame):
    """
    Compute optical flow using the Lucas-Kanade method between two frames.
    
    Returns:
        good_old: Array of points from the previous frame.
        good_new: Array of corresponding points from the next frame.
    """
    # Convert frames to grayscale
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

    # Parameters for Lucas-Kanade optical flow
    lk_params = dict(winSize=(21, 21),
                     maxLevel=3,
                     criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 30, 0.01))

    # Parameters for Shi-Tomasi corner detection (good features to track)
    feature_params = dict(maxCorners=3000, qualityLevel=0.01, minDistance=0.1)
    
    # Detect features in the previous frame
    p0 = cv2.goodFeaturesToTrack(prev_gray, mask=None, **feature_params)
    if p0 is None:
        return [], []

    # Calculate optical flow (find corresponding points in the next frame)
    p1, st, err = cv2.calcOpticalFlowPyrLK(prev_gray, next_gray, p0, None, **lk_params)

    # Ensure valid output and select good points based on the status array
    if p1 is not None and st is not None:
        st = st.flatten()
        good_old = p0[st == 1]
        good_new = p1[st == 1]
    else:
        good_old, good_new = [], []

    return good_old, good_new

def create_mei_mhi(flow, shape, tau=10):
    """
    Create Motion Energy Image (MEI) and Motion History Image (MHI) from optical flow vectors.
    
    Args:
        flow: Tuple containing (good_old, good_new) points.
        shape: Tuple defining the output image size (height, width).
        tau: Time constant for motion decay in the MHI.
        
    Returns:
        mei: The Motion Energy Image (binary representation of motion).
        mhi: The Motion History Image (captures motion intensity with decay).
    """
    # Initialize MEI and MHI as zero arrays
    mei = np.zeros(shape, dtype=np.float32)
    mhi = np.zeros(shape, dtype=np.float32)

    # Iterate over each pair of corresponding points to draw motion vectors
    for (new, old) in zip(flow[1], flow[0]):
        x1, y1 = new.ravel()
        x2, y2 = old.ravel()
        
        # Draw a line for the motion on the MEI (binary, using a fixed thickness)
        cv2.line(mei, (int(x1), int(y1)), (int(x2), int(y2)), 255, 2)
        
        # Draw the same line on the MHI (this will later be decayed over time)
        cv2.line(mhi, (int(x1), int(y1)), (int(x2), int(y2)), 255, 2)

    # Apply decay to the MHI (simulate motion fading over time)
    mhi[mhi > 0] -= 255 / tau  
    mhi[mhi < 0] = 0  # Clip negative values to 0

    return mei, mhi

def frames_extraction_OF(video_path, SEQUENCE_LENGTH, OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH):
    """
    Extracts Motion Energy Images (MEI) from a video by computing optical flow between frame pairs.
    
    Args:
        video_path: Path to the video file.
        SEQUENCE_LENGTH: Number of frame pairs (and thus MEI images) to extract.
        IMAGE_HEIGHT: Target height for resizing frames.
        IMAGE_WIDTH: Target width for resizing frames.
    
    Returns:
        A 4D NumPy array of shape (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 1)
        containing the normalized MEI images.
    """
    frames_list2 = []

    # Open the video file
    video_reader = cv2.VideoCapture(video_path)
    if not video_reader.isOpened():
        print(f"Error: Could not open video {video_path}.")
        return frames_list2

    # Total frames and skip window calculation for even sampling
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / SEQUENCE_LENGTH), 1)

    # Iterate over the video using the skip window to select frame pairs
    for frame_counter in range(0, video_frames_count - skip_frames_window, skip_frames_window):
        # Read the previous frame
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter)
        success, prev_frame = video_reader.read()
        if not success:
            break

        # Read the next frame
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter + skip_frames_window)
        success, next_frame = video_reader.read()
        if not success:
            break

        # Resize frames to target dimensions. Note: cv2.resize expects (width, height)
        prev_frame_resized = cv2.resize(prev_frame, (OF_IMAGE_WIDTH, OF_IMAGE_HEIGHT))
        next_frame_resized = cv2.resize(next_frame, (OF_IMAGE_WIDTH, OF_IMAGE_HEIGHT))

        # Compute optical flow between the two frames
        good_old, good_new = compute_optical_flow(prev_frame_resized, next_frame_resized)

        # If no valid optical flow vectors were found, skip this pair
        if len(good_old) == 0 or len(good_new) == 0:
            print(f"Warning: No optical flow vectors found for frames {frame_counter} and {frame_counter + skip_frames_window}.")
            continue

        # Create the Motion Energy Image (MEI) from the optical flow vectors
        mei, _ = create_mei_mhi((good_old, good_new), (OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH), tau=10)

        # Normalize the MEI to 0-255 and convert to an 8-bit image for visualization
        mei_norm = cv2.normalize(mei, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)

        # Expand dimensions to add a channel axis (resulting in shape: H x W x 1)
        mei_norm = np.expand_dims(mei_norm, axis=-1)

        # Append the normalized MEI image to the list
        frames_list2.append(mei_norm)

    # Release the video capture
    video_reader.release()

    # If fewer than SEQUENCE_LENGTH frames were extracted, pad with zero-frames
    while len(frames_list2) < SEQUENCE_LENGTH:
        frames_list2.append(np.zeros((OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH, 1), dtype=np.uint8))

    # If more than SEQUENCE_LENGTH frames were collected, truncate the list
    if len(frames_list2) > SEQUENCE_LENGTH:
        frames_list2 = frames_list2[:SEQUENCE_LENGTH]

    # Convert the list of frames to a 4D NumPy array
    frames_list2 = np.stack(frames_list2, axis=0)

    return frames_list2

# %% [markdown]
# ## Dataset Creation

# %% [markdown]
# 1st Stream

# %%
def create_dataset_1st():
    """Creates the dataset for the first (RGB) stream with flipping and rotation augmentations."""
    features1 = []
    labels1 = []
    video_files_paths1 = []
    
    # Create an ImageDataGenerator with rotation and horizontal flip augmentations.
    datagen = ImageDataGenerator(
        rotation_range=15,        # Allow rotations up to 15 degrees.
        horizontal_flip=True,     # Enable horizontal flipping.
        fill_mode='nearest'       # Strategy to fill in newly created pixels.
    )
    
    # Iterate over each class in the dataset.
    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of class: {class_name}')
        class_dir = os.path.join(DATASET_DIR, class_name)
        files_list = os.listdir(class_dir)
        
        # Process each video file in the current class directory.
        for file_name in files_list:
            video_file_path = os.path.join(class_dir, file_name)
            
            try:
                # Extract the original frames using the defined function.
                frames = frames_extraction_RGB(video_file_path)
                
                # Only proceed if the number of extracted frames equals SEQUENCE_LENGTH.
                if len(frames) == SEQUENCE_LENGTH:
                    # Add the original frames to the features list.
                    features1.append(frames)
                    labels1.append(class_index)
                    video_files_paths1.append(video_file_path)
                    
                    # Create an augmented version of the frames.
                    augmented_frames = []
                    # Generate a random seed that will be used for every frame in the sequence
                    # to ensure a consistent transformation across the entire video.
                    seed = np.random.randint(1000)
                    
                    for frame in frames:
                        # Expand dimensions to match the input shape expected by ImageDataGenerator.
                        frame_expanded = np.expand_dims(frame, 0)
                        it = datagen.flow(frame_expanded, batch_size=1, seed=seed)
                        # Generate the augmented frame.
                        augmented_frame = next(it)[0]
                        augmented_frames.append(augmented_frame)
                    
                    # Append the augmented frames as a separate sample.
                    features1.append(augmented_frames)
                    labels1.append(class_index)
                    video_files_paths1.append(video_file_path + '_aug')
                else:
                    print(f"Warning: {video_file_path} did not yield {SEQUENCE_LENGTH} frames.")
            
            except Exception as e:
                print(f"Warning: Processing failed for {video_file_path}: {str(e)}")
                continue
    
    # Convert lists to NumPy arrays.
    features1 = np.array(features1)
    labels1 = np.array(labels1)
    
    return features1, labels1, video_files_paths1

# %%
output_folder = "rgb_data"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Create your dataset for the RGB stream
features1, labels1, video_files_paths1 = create_dataset_1st()

# Display dataset information
print(f"Features shape: {features1.shape}")
print(f"Labels shape: {labels1.shape}")
print(f"Number of videos (including augmented): {len(video_files_paths1)}")

# Save the features, labels, and video paths into .npy files inside 'rgb_data'
np.save(os.path.join(output_folder, "features1.npy"), features1)
np.save(os.path.join(output_folder, "labels1.npy"), labels1)
np.save(os.path.join(output_folder, "video_files_paths1.npy"), video_files_paths1)
# Out:
# Extracting Data of class: LumbarSideBends
# Extracting Data of class: QuadrupedThoracicRotation
# Extracting Data of class: SupineNeckLift
# Features shape: (578, 30, 96, 96, 3)
# Labels shape: (578,)
# Number of videos (including augmented): 578

# %%
#convert labels into one-hot encoded vectors
one_hot_encoded_labels1 = to_categorical(labels1, num_classes=len(CLASSES_LIST))

# %%
# Display the converted labels
unique_labels1, counts1 = np.unique(labels1, return_counts=True)
for label, count in zip(unique_labels1, counts1):
    print(f"Label {label}: {count} instances")
# Out:
# Label 0: 192 instances
# Label 1: 194 instances
# Label 2: 192 instances

# %%
plt.figure(figsize=(15, 5))

for i, label in enumerate(unique_labels1):
    # Find the first index of the current label
    index = np.where(labels1 == label)[0][0]

#Extract the corresponding video frames
    frames = features1[index]

#Select a random frame instead of the middle one
    random_frame = frames[np.random.randint(0, len(frames))]

#Plot the frame
    plt.subplot(1, 3, i + 1)
    plt.imshow(random_frame)
    plt.title(f"Label: {label}")
    plt.axis('off')

plt.show()

# %% [markdown]
# Show Sample Augmeted Frames

# %%
plt.figure(figsize=(15, 5))

# Get unique labels (assumes labels1 is a NumPy array)
unique_labels = np.unique(labels1)

for i, label in enumerate(unique_labels):
    # Find all indices where the sample has the current label and is an augmented sample.
    # We check if '_aug' is in the corresponding file path.
    augmented_indices = [
        j for j, (lab, path) in enumerate(zip(labels1, video_files_paths1))
        if lab == label and '_aug' in path
    ]
    
    # If no augmented sample is found, use the first original sample.
    if len(augmented_indices) == 0:
        print(f"No augmented sample found for label {label}. Using original sample.")
        index = np.where(labels1 == label)[0][0]
    else:
        index = augmented_indices[0]
    
    # Extract the video frames for the chosen sample.
    frames = features1[index]
    
    # Select a random frame from the sequence.
    random_frame = frames[np.random.randint(0, len(frames))]
    
    # Plot the frame.
    plt.subplot(1, len(unique_labels), i + 1)
    plt.imshow(random_frame)
    plt.title(f"Label: {label} (augmented)")
    plt.axis('off')

plt.show()

# %% [markdown]
# 2nd Stream

# %%
def create_dataset_2nd():
    """Creates the dataset with only flipping and rotation augmentations for the optical flow stream."""
    features2 = []
    labels2 = []
    video_files_paths2 = []
    
    # Create an ImageDataGenerator for applying rotation and horizontal flip augmentations.
    datagen = ImageDataGenerator(
        rotation_range=15,        # Rotate images up to 15 degrees.
        horizontal_flip=True,     # Apply horizontal flipping.       # Define how to fill pixels when transformations create new empty areas.
    )
    
    # Loop over each class directory
    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of class: {class_name}')
        class_dir = os.path.join(DATASET_DIR, class_name)
        files_list = os.listdir(class_dir)
        
        for file_name in files_list:
            video_file_path = os.path.join(class_dir, file_name)
            
            try:
                # Extract the optical flow frames using the frames_extraction_OF function.
                frames = frames_extraction_OF(video_file_path, SEQUENCE_LENGTH, OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH)
                
                if len(frames) == SEQUENCE_LENGTH:
                    # Save the original optical flow frames.
                    features2.append(frames)
                    labels2.append(class_index)
                    video_files_paths2.append(video_file_path)
                    
                    # Create an augmented version of the optical flow frames.
                    augmented_frames = []
                    seed = np.random.randint(1000)  # Use the same seed for all frames to maintain consistency across the sequence.
                    
                    for frame in frames:
                        frame_expanded = np.expand_dims(frame, 0)
                        it = datagen.flow(frame_expanded, batch_size=1, seed=seed)
                        augmented_frame = next(it)[0]
                        augmented_frames.append(augmented_frame)
                    
                    # Append the augmented sample.
                    features2.append(augmented_frames)
                    labels2.append(class_index)
                    video_files_paths2.append(video_file_path + '_aug')
            
            except Exception as e:
                print(f"Warning: Processing failed for {video_file_path}: {str(e)}")
                continue
    
    # Convert the collected lists to NumPy arrays.
    features2 = np.array(features2)
    labels2 = np.array(labels2)
    
    return features2, labels2, video_files_paths2

# %%
# Create the folder 'opticalflow_data' if it doesn't already exist
output_folder = "opticalflow_data"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Create your dataset for the optical flow stream
features2, labels2, video_files_paths2 = create_dataset_2nd()

# Display dataset information
print(f"Features shape: {features2.shape}")
print(f"Labels shape: {labels2.shape}")
print(f"Number of videos (including augmented): {len(video_files_paths2)}")

# Save the features, labels, and video paths into .npy files inside 'opticalflow_data'
np.save(os.path.join(output_folder, "features2.npy"), features2)
np.save(os.path.join(output_folder, "labels2.npy"), labels2)
np.save(os.path.join(output_folder, "video_files_paths2.npy"), video_files_paths2)
# Out:
# Extracting Data of class: LumbarSideBends
# Extracting Data of class: QuadrupedThoracicRotation
# Extracting Data of class: SupineNeckLift
# Features shape: (578, 30, 224, 224, 1)
# Labels shape: (578,)
# Number of videos (including augmented): 578

# %%
#convert labels into one-hot encoded vectors
one_hot_encoded_labels2 = to_categorical(labels2,num_classes=len(CLASSES_LIST))

# %%
# Display the converted labels 
unique_labels2, counts2 = np.unique(labels2, return_counts=True)
for label, count in zip(unique_labels2, counts2):
    print(f"Label {label}: {count} instances")
# Out:
# Label 0: 192 instances
# Label 1: 194 instances
# Label 2: 192 instances

# %%
plt.figure(figsize=(15, 5))

for i, label in enumerate(unique_labels2):
    # Find the first index of the current label
    index = np.where(labels2 == label)[0][0]

#Extract the corresponding video frames
    frames = features2[index]

#Select a random frame instead of the middle one
    random_frame = frames[np.random.randint(0, len(frames))]

#Plot the frame
    plt.subplot(1, 3, i + 1)
    plt.imshow(random_frame, cmap="grey")
    plt.title(f"Label: {label}")
    plt.axis('off')

plt.show()

# %% [markdown]
# Show Sample Augmented Frames:

# %%
plt.figure(figsize=(15, 5))

# Get unique labels (assumes labels1 is a NumPy array)
unique_labels = np.unique(labels2)

for i, label in enumerate(unique_labels):
    # Find all indices where the sample has the current label and is an augmented sample.
    # We check if '_aug' is in the corresponding file path.
    augmented_indices = [
        j for j, (lab, path) in enumerate(zip(labels2, video_files_paths2))
        if lab == label and '_aug' in path
    ]
    
    # If no augmented sample is found, use the first original sample.
    if len(augmented_indices) == 0:
        print(f"No augmented sample found for label {label}. Using original sample.")
        index = np.where(labels1 == label)[0][0]
    else:
        index = augmented_indices[0]
    
    # Extract the video frames for the chosen sample.
    frames = features2[index]
    
    # Select a random frame from the sequence.
    random_frame = frames[np.random.randint(0, len(frames))]
    
    # Plot the frame.
    plt.subplot(1, len(unique_labels), i + 1)
    plt.imshow(random_frame,cmap="grey")
    plt.title(f"Label: {label} (augmented)")
    plt.axis('off')

plt.show()

# %% [markdown]
# ## Split Data into Train, Test, and Validation

# %% [markdown]
# For 1st Stream (RBG Data)

# %%
features_train1, features_test1, labels_train1, labels_test1 = train_test_split(features1, one_hot_encoded_labels1,
                                                                                test_size=0.20, shuffle = True, 
                                                                                random_state = seed_constant)
features_train1, features_val1, labels_train1, labels_val1 = train_test_split(
    features_train1, labels_train1, test_size=0.20, shuffle=True, random_state=seed_constant
)
output_folder = "rgb_data"
# Save the features arrays to the rgb_data folder.
np.save(os.path.join(output_folder, "features_train1.npy"), features_train1)
np.save(os.path.join(output_folder, "features_val1.npy"), features_val1)
np.save(os.path.join(output_folder, "features_test1.npy"), features_test1)

# Optionally, save the corresponding labels as well.
np.save(os.path.join(output_folder, "labels_train1.npy"), labels_train1)
np.save(os.path.join(output_folder, "labels_val1.npy"), labels_val1)
np.save(os.path.join(output_folder, "labels_test1.npy"), labels_test1)

# Display the number of samples in each set
print(f"Number of training samples: {len(features_train1)}")
print(f"Number of validation samples: {len(features_val1)}")
print(f"Number of testing samples: {len(features_test1)}")
# Out:
# Number of training samples: 369
# Number of validation samples: 93
# Number of testing samples: 116

# %% [markdown]
# For 2nd Stream (OF Data)

# %%
features_train2, features_test2, labels_train2, labels_test2 = train_test_split(features2, one_hot_encoded_labels2,
                                                                                test_size=0.20, shuffle = True, 
                                                                                random_state = seed_constant)
features_train2, features_val2, labels_train2, labels_val2 = train_test_split(
    features_train2, labels_train2, test_size=0.20, shuffle=True, random_state=seed_constant
)
output_folder = "opticalflow_data"
# Save the features arrays to the rgb_data folder.
np.save(os.path.join(output_folder, "features_train2.npy"), features_train2)
np.save(os.path.join(output_folder, "features_val2.npy"), features_val2)
np.save(os.path.join(output_folder, "features_test2.npy"), features_test2)

# Optionally, save the corresponding labels as well.
np.save(os.path.join(output_folder, "labels_train2.npy"), labels_train2)
np.save(os.path.join(output_folder, "labels_val2.npy"), labels_val2)
np.save(os.path.join(output_folder, "labels_test2.npy"), labels_test2)

# Display the number of samples in each set
print(f"Number of training samples: {len(features_train2)}")
print(f"Number of validation samples: {len(features_val2)}")
print(f"Number of testing samples: {len(features_test2)}")
# Out:
# Number of training samples: 369
# Number of validation samples: 93
# Number of testing samples: 116

# %% [markdown]
# ## Implement 2stream Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, TimeDistributed, GlobalAveragePooling2D, Bidirectional, GRU, Dropout,SpatialDropout2D, Dense, Conv2D, MaxPooling2D, Concatenate, Dense, Dropout, Lambda
from tensorflow.keras.models import Model

# %%
# Define input shapes
rgb_input_shape = (features1.shape[1:])  # (Time steps, Height, Width, Channels)
of_input_shape = (features2.shape[1:])   # (Time steps, Height, Width, OF Channels)
num_classes = 3 # Example: 10 action classes

print(rgb_input_shape)
print(of_input_shape)
# Out:
# (30, 96, 96, 3)
# (30, 224, 224, 1)

# %% [markdown]
# Define the RGB CNN Architecture

# %%
def create_rgb_stream_model(seq_length=30, input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3),
                            gru_units=64, dropout_rate=0.5, feature_dim=64):
    base_cnn = tf.keras.applications.MobileNetV2(input_shape=input_shape,
                                                 include_top=False,
                                                 weights='imagenet')
    
    base_cnn.trainable = False

    rgb_input = Input(shape=(seq_length,) + input_shape, name="rgb_input")

    x = TimeDistributed(base_cnn, name="time_distributed_cnn")(rgb_input)
    x = TimeDistributed(GlobalAveragePooling2D(), name="time_distributed_gap")(x)
    x = GRU(gru_units, return_sequences=False, name="gru_layer")(x)
    x = Dropout(dropout_rate, name="gru_dropout")(x)
    
    output = Dense(feature_dim, activation='relu', name="rgb_feature_vector")(x)
    model = Model(inputs=rgb_input, outputs=output, name="RGB_Stream_Model")
    return model

# %%
# Create the RGB model
rgb_model = create_rgb_stream_model()
rgb_model.summary()
# Out:
# Model: "RGB_Stream_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rgb_input (InputLayer)      [(None, 30, 96, 96, 3)]   0
#
#  time_distributed_cnn (TimeD  (None, 30, 3, 3, 1280)   2257984
#  istributed)
#
#  time_distributed_gap (TimeD  (None, 30, 1280)         0
#  istributed)
#
#  gru_layer (GRU)             (None, 64)                258432
#
#  gru_dropout (Dropout)       (None, 64)                0
#
#  rgb_feature_vector (Dense)  (None, 64)                4160
#
# =================================================================
# Total params: 2,520,576
# Trainable params: 262,592
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# Define the Optical Flow CNN architecture

# %%
def create_optical_flow_stream_model(seq_length=30,
                                   input_shape=(OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH, 1),
                                   gru_units=64,
                                   dropout_rate=0.3,
                                   num_classes=10):
    """
    Creates a simplified temporal CNN stream for optical flow input with GRU layer.
    Optimized for memory efficiency while maintaining motion capture capabilities.
    
    Args:
        seq_length (int): Number of consecutive optical flow frames (time steps)
        input_shape (tuple): Shape of each flow frame (H, W, Channels)
        gru_units (int): Number of units in the GRU layer
        dropout_rate (float): Dropout rate for regularization
        num_classes (int): Number of output classes for classification
        
    Returns:
        model (tf.keras.Model): A Keras model for the optical flow stream
    """
    
    # Input: Sequence of optical flow frames
    flow_input = Input(shape=(seq_length,) + input_shape, name="flow_input")
    
    # Block 1: Initial motion feature extraction
    # Larger kernel (7x7) to capture broader motion patterns
    x = TimeDistributed(
        Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2),
               padding='same', activation='relu'),
        name="td_conv1"
    )(flow_input)
    
    x = TimeDistributed(
        MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        name="td_pool1"
    )(x)
    
    # Block 2: Motion refinement
    # Medium kernel (5x5) for intermediate feature processing
    x = TimeDistributed(
        Conv2D(filters=128, kernel_size=(5, 5), strides=(2, 2),
               padding='same', activation='relu'),
        name="td_conv2"
    )(x)
    
    x = TimeDistributed(
        MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        name="td_pool2"
    )(x)
    
    # Block 3: Final feature extraction
    x = TimeDistributed(
        Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1),
               padding='same', activation='relu'),
        name="td_conv3"
    )(x)
    
    x = TimeDistributed(
        MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        name="td_pool3"
    )(x)
    
    # Flatten features for GRU
    x = TimeDistributed(Flatten(), name="td_flatten")(x)
    
    # GRU for temporal dynamics
    x = GRU(gru_units, return_sequences=False, name="gru_flow")(x)
    x = Dropout(dropout_rate, name="dropout1")(x)
    
    # Single dense layer before classification
    x = Dense(512, activation='relu', name="fc1")(x)
    x = Dropout(dropout_rate, name="dropout2")(x)
    
    # Classification layer
    output = Dense(num_classes, activation='softmax', name="predictions")(x)
    
    # Build model
    model = Model(inputs=flow_input, outputs=output, name="OpticalFlow_Stream_Model")
    
    return model

# %%
optical_flow_model = create_optical_flow_stream_model()  # Corrected call
optical_flow_model.summary()
# Out:
# Model: "OpticalFlow_Stream_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flow_input (InputLayer)     [(None, 30, 224, 224, 1)  0
#                              ]
#
#  td_conv1 (TimeDistributed)  (None, 30, 112, 112, 64)  3200
#
#  td_pool1 (TimeDistributed)  (None, 30, 56, 56, 64)    0
#
#  td_conv2 (TimeDistributed)  (None, 30, 28, 28, 128)   204928
#
#  td_pool2 (TimeDistributed)  (None, 30, 14, 14, 128)   0
#
#  td_conv3 (TimeDistributed)  (None, 30, 14, 14, 256)   295168
#
#  td_pool3 (TimeDistributed)  (None, 30, 7, 7, 256)     0
#
#  td_flatten (TimeDistributed  (None, 30, 12544)        0
#  )
#
#  gru_flow (GRU)              (None, 64)                2421120
#
#  dropout1 (Dropout)          (None, 64)                0
#
#  fc1 (Dense)                 (None, 512)               33280
#
#  dropout2 (Dropout)          (None, 512)               0
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 2,962,826
# Trainable params: 2,962,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
def create_late_fusion_model(rgb_model, flow_model, num_classes, 
                                      fusion_dropout=0.5, dense_units=128):
    """
    Creates an improved late fusion model that combines the feature outputs from the 
    RGB stream and the Optical Flow stream models.
    """
    
    # Get the inputs from each branch.
    rgb_input = rgb_model.input
    flow_input = flow_model.input
    
    # Extract the feature outputs from each stream.
    rgb_features = rgb_model.output 
    flow_features = flow_model.output 
    
    # Apply Batch Normalization to each modality's features.
    rgb_features = BatchNormalization(name="rgb_bn")(rgb_features)
    flow_features = BatchNormalization(name="flow_bn")(flow_features)
    
    # Fuse the features using concatenation.
    fused_features = Concatenate(name='fusion_concat')([rgb_features, flow_features])
    
    # First transformation block after fusion.
    x = Dropout(fusion_dropout, name='fusion_dropout_1')(fused_features)
    x = Dense(dense_units, name='fusion_dense_1')(x)
    x = BatchNormalization(name='fusion_bn_1')(x)
    x = Activation('relu', name='fusion_act_1')(x)
    
    # Second transformation block for added non-linearity.
    x = Dropout(fusion_dropout, name='fusion_dropout_2')(x)
    x = Dense(dense_units // 2, name='fusion_dense_2')(x)
    x = BatchNormalization(name='fusion_bn_2')(x)
    x = Activation('relu', name='fusion_act_2')(x)
    
    # Final classification layer.
    outputs = Dense(num_classes, activation='softmax', name='output')(x)
    
    model = Model(inputs=[rgb_input, flow_input], outputs=outputs, name='Improved_Late_Fusion_Model')
    return model

# %% [markdown]
# ##### Display Architecture

# %%
num_classes = 3
late_fusion_model = create_late_fusion_model(rgb_model, optical_flow_model, num_classes)
late_fusion_model.summary()
# Out:
# Model: "Improved_Late_Fusion_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  flow_input (InputLayer)        [(None, 30, 224, 22  0           []
#                                 4, 1)]
#
#  td_conv1 (TimeDistributed)     (None, 30, 112, 112  3200        ['flow_input[0][0]']
#                                 , 64)
#
#  td_pool1 (TimeDistributed)     (None, 30, 56, 56,   0           ['td_conv1[0][0]']
#                                 64)
#
#  td_conv2 (TimeDistributed)     (None, 30, 28, 28,   204928      ['td_pool1[0][0]']
#                                 128)
#
#  td_pool2 (TimeDistributed)     (None, 30, 14, 14,   0           ['td_conv2[0][0]']
#                                 128)
#
#  td_conv3 (TimeDistributed)     (None, 30, 14, 14,   295168      ['td_pool2[0][0]']
#                                 256)
#
#  td_pool3 (TimeDistributed)     (None, 30, 7, 7, 25  0           ['td_conv3[0][0]']
#                                 6)
#
#  rgb_input (InputLayer)         [(None, 30, 96, 96,  0           []
#                                  3)]
#
#  td_flatten (TimeDistributed)   (None, 30, 12544)    0           ['td_pool3[0][0]']
#
#  time_distributed_cnn (TimeDist  (None, 30, 3, 3, 12  2257984    ['rgb_input[0][0]']
#  ributed)                       80)
#
#  gru_flow (GRU)                 (None, 64)           2421120     ['td_flatten[0][0]']
#
#  time_distributed_gap (TimeDist  (None, 30, 1280)    0           ['time_distributed_cnn[0][0]']
#  ributed)
#
#  dropout1 (Dropout)             (None, 64)           0           ['gru_flow[0][0]']
#
#  gru_layer (GRU)                (None, 64)           258432      ['time_distributed_gap[0][0]']
#
#  fc1 (Dense)                    (None, 512)          33280       ['dropout1[0][0]']
#
#  gru_dropout (Dropout)          (None, 64)           0           ['gru_layer[0][0]']
#
#  dropout2 (Dropout)             (None, 512)          0           ['fc1[0][0]']
#
#  rgb_feature_vector (Dense)     (None, 64)           4160        ['gru_dropout[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['dropout2[0][0]']
#
#  rgb_bn (BatchNormalization)    (None, 64)           256         ['rgb_feature_vector[0][0]']
#
#  flow_bn (BatchNormalization)   (None, 10)           40          ['predictions[0][0]']
#
#  fusion_concat (Concatenate)    (None, 74)           0           ['rgb_bn[0][0]',
#                                                                   'flow_bn[0][0]']
#
#  fusion_dropout_1 (Dropout)     (None, 74)           0           ['fusion_concat[0][0]']
#
#  fusion_dense_1 (Dense)         (None, 128)          9600        ['fusion_dropout_1[0][0]']
#
#  fusion_bn_1 (BatchNormalizatio  (None, 128)         512         ['fusion_dense_1[0][0]']
#  n)
#
#  fusion_act_1 (Activation)      (None, 128)          0           ['fusion_bn_1[0][0]']
#
#  fusion_dropout_2 (Dropout)     (None, 128)          0           ['fusion_act_1[0][0]']
#
#  fusion_dense_2 (Dense)         (None, 64)           8256        ['fusion_dropout_2[0][0]']
#
#  fusion_bn_2 (BatchNormalizatio  (None, 64)          256         ['fusion_dense_2[0][0]']
#  n)
#
#  fusion_act_2 (Activation)      (None, 64)           0           ['fusion_bn_2[0][0]']
#
#  output (Dense)                 (None, 3)            195         ['fusion_act_2[0][0]']
#
# ==================================================================================================
# Total params: 5,502,517
# Trainable params: 3,244,001
# Non-trainable params: 2,258,516
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# -------------------------------
# Load Data from the npy files
# -------------------------------

# Load RGB stream data from the "rgb_data" folder.
features_train1 = np.load('rgb_data/features_train1.npy')
labels_train1   = np.load('rgb_data/labels_train1.npy')
features_val1   = np.load('rgb_data/features_val1.npy')
labels_val1     = np.load('rgb_data/labels_val1.npy')

# Load Optical Flow stream data from the "opticalflow_data" folder.
features_train2 = np.load('opticalflow_data/features_train2.npy')
features_val2   = np.load('opticalflow_data/features_val2.npy')

# Convert features (and labels if necessary) to float32.
features_train1 = features_train1.astype(np.float32)
features_val1   = features_val1.astype(np.float32)
features_train2 = features_train2.astype(np.float32)
features_val2   = features_val2.astype(np.float32)
labels_train1   = labels_train1.astype(np.float32)
labels_val1     = labels_val1.astype(np.float32)

# Optionally, print shapes to verify they match your model's expectations.
print("features_train1 shape:", features_train1.shape)
print("features_train2 shape:", features_train2.shape)
print("labels_train1 shape:", labels_train1.shape)
print("features_val1 shape:", features_val1.shape)
print("features_val2 shape:", features_val2.shape)
print("labels_val1 shape:", labels_val1.shape)

# -------------------------------
# Compile the Late Fusion Model
# -------------------------------
late_fusion_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Set up early stopping to monitor validation loss.
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# -------------------------------
# Train the Model
# -------------------------------
history = late_fusion_model.fit(
    [features_train1, features_train2],  # Two inputs: RGB and Optical Flow features.
    labels_train1,                        # One-hot encoded labels.
    validation_data=([features_val1, features_val2], labels_val1),
    epochs=100,
    batch_size=4,
    callbacks=[early_stopping]
)
# Out:
# features_train1 shape: (369, 30, 96, 96, 3)
# features_train2 shape: (369, 30, 224, 224, 1)
# labels_train1 shape: (369, 3)
# features_val1 shape: (93, 30, 96, 96, 3)
# features_val2 shape: (93, 30, 224, 224, 1)
# labels_val1 shape: (93, 3)
# Epoch 1/100
# 93/93 [==============================] - 45s 152ms/step - loss: 1.4704 - accuracy: 0.2981 - val_loss: 1.1118 - val_accuracy: 0.3441
# Epoch 2/100
# 93/93 [==============================] - 10s 105ms/step - loss: 1.3488 - accuracy: 0.3252 - val_loss: 1.1071 - val_accuracy: 0.3333
# Epoch 3/100
# 93/93 [==============================] - 10s 102ms/step - loss: 1.3264 - accuracy: 0.3306 - val_loss: 1.0906 - val_accuracy: 0.3871
# Epoch 4/100
# 93/93 [==============================] - 10s 104ms/step - loss: 1.2891 - accuracy: 0.3496 - val_loss: 1.0556 - val_accuracy: 0.3978
# Epoch 5/100
# 93/93 [==============================] - 10s 103ms/step - loss: 1.2486 - accuracy: 0.3388 - val_loss: 1.0365 - val_accuracy: 0.4086
# Epoch 6/100
# 93/93 [==============================] - 10s 103ms/step - loss: 1.2770 - accuracy: 0.3333 - val_loss: 1.0300 - val_accuracy: 0.4086
# Epoch 7/100
# 93/93 [==============================] - 10s 103ms/step - loss: 1.2582 - accuracy: 0.3062 - val_loss: 1.0451 - val_accuracy: 0.4301
# Epoch 8/100
# 93/93 [==============================] - 10s 102ms/step - loss: 1.1641 - accuracy: 0.3875 - val_loss: 1.0285 - val_accuracy: 0.4409
# Epoch 9/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.2063 - accuracy: 0.3388 - val_loss: 1.0225 - val_accuracy: 0.4946
# Epoch 10/100
# 93/93 [==============================] - 10s 102ms/step - loss: 1.1395 - accuracy: 0.4092 - val_loss: 1.0190 - val_accuracy: 0.5376
# Epoch 11/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.1916 - accuracy: 0.3225 - val_loss: 1.0289 - val_accuracy: 0.4839
# Epoch 12/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.2188 - accuracy: 0.3740 - val_loss: 1.0068 - val_accuracy: 0.4946
# Epoch 13/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.1810 - accuracy: 0.3388 - val_loss: 1.0095 - val_accuracy: 0.4946
# Epoch 14/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.1412 - accuracy: 0.3930 - val_loss: 0.9810 - val_accuracy: 0.6129
# Epoch 15/100
# 93/93 [==============================] - 10s 103ms/step - loss: 1.1079 - accuracy: 0.3957 - val_loss: 0.9553 - val_accuracy: 0.6129
# Epoch 16/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0997 - accuracy: 0.4119 - val_loss: 0.9678 - val_accuracy: 0.5806
# Epoch 17/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.1480 - accuracy: 0.3930 - val_loss: 0.9915 - val_accuracy: 0.5376
# Epoch 18/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.1542 - accuracy: 0.4282 - val_loss: 0.9677 - val_accuracy: 0.5161
# Epoch 19/100
# 93/93 [==============================] - 10s 103ms/step - loss: 1.1011 - accuracy: 0.4255 - val_loss: 0.9860 - val_accuracy: 0.4839
# Epoch 20/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.1485 - accuracy: 0.4011 - val_loss: 1.0114 - val_accuracy: 0.5161
# Epoch 21/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.1230 - accuracy: 0.4201 - val_loss: 0.9857 - val_accuracy: 0.5269
# Epoch 22/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.0865 - accuracy: 0.4770 - val_loss: 0.9541 - val_accuracy: 0.6237
# Epoch 23/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.1271 - accuracy: 0.4201 - val_loss: 0.9485 - val_accuracy: 0.5699
# Epoch 24/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0990 - accuracy: 0.4228 - val_loss: 0.9380 - val_accuracy: 0.5914
# Epoch 25/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0693 - accuracy: 0.4634 - val_loss: 0.9333 - val_accuracy: 0.6237
# Epoch 26/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.0647 - accuracy: 0.4661 - val_loss: 0.9334 - val_accuracy: 0.6559
# Epoch 27/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0762 - accuracy: 0.4472 - val_loss: 0.9326 - val_accuracy: 0.6237
# Epoch 28/100
# 93/93 [==============================] - 10s 103ms/step - loss: 1.0672 - accuracy: 0.4553 - val_loss: 0.9075 - val_accuracy: 0.6237
# Epoch 29/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0807 - accuracy: 0.4228 - val_loss: 0.8508 - val_accuracy: 0.7634
# Epoch 30/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0521 - accuracy: 0.4959 - val_loss: 0.8388 - val_accuracy: 0.7742
# Epoch 31/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.0305 - accuracy: 0.4905 - val_loss: 0.8473 - val_accuracy: 0.6882
# Epoch 32/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0010 - accuracy: 0.5149 - val_loss: 0.8278 - val_accuracy: 0.7419
# Epoch 33/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0213 - accuracy: 0.5014 - val_loss: 0.8201 - val_accuracy: 0.7204
# Epoch 34/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0618 - accuracy: 0.4526 - val_loss: 0.8022 - val_accuracy: 0.7742
# Epoch 35/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.0362 - accuracy: 0.4797 - val_loss: 0.8123 - val_accuracy: 0.7419
# Epoch 36/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0109 - accuracy: 0.4932 - val_loss: 0.7836 - val_accuracy: 0.7634
# Epoch 37/100
# 93/93 [==============================] - 9s 102ms/step - loss: 1.0021 - accuracy: 0.5041 - val_loss: 0.7531 - val_accuracy: 0.8172
# Epoch 38/100
# 93/93 [==============================] - 9s 101ms/step - loss: 1.0118 - accuracy: 0.4905 - val_loss: 0.7798 - val_accuracy: 0.7849
# Epoch 39/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.9958 - accuracy: 0.5176 - val_loss: 0.7542 - val_accuracy: 0.7742
# Epoch 40/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.9576 - accuracy: 0.5339 - val_loss: 0.7092 - val_accuracy: 0.8710
# Epoch 41/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.9770 - accuracy: 0.5366 - val_loss: 0.7413 - val_accuracy: 0.8172
# Epoch 42/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.9582 - accuracy: 0.5420 - val_loss: 0.7235 - val_accuracy: 0.7957
# Epoch 43/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.9456 - accuracy: 0.5556 - val_loss: 0.6964 - val_accuracy: 0.7957
# Epoch 44/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.9414 - accuracy: 0.5583 - val_loss: 0.7056 - val_accuracy: 0.7742
# Epoch 45/100
# 93/93 [==============================] - 10s 103ms/step - loss: 0.9432 - accuracy: 0.5501 - val_loss: 0.6588 - val_accuracy: 0.7957
# Epoch 46/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.8800 - accuracy: 0.6206 - val_loss: 0.6555 - val_accuracy: 0.8172
# Epoch 47/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.9010 - accuracy: 0.5989 - val_loss: 0.6356 - val_accuracy: 0.8172
# Epoch 48/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.8718 - accuracy: 0.6070 - val_loss: 0.6226 - val_accuracy: 0.8280
# Epoch 49/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.8943 - accuracy: 0.5962 - val_loss: 0.6003 - val_accuracy: 0.8172
# Epoch 50/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.8263 - accuracy: 0.6152 - val_loss: 0.5788 - val_accuracy: 0.8387
# Epoch 51/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.8912 - accuracy: 0.5881 - val_loss: 0.5875 - val_accuracy: 0.8280
# Epoch 52/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.8213 - accuracy: 0.6477 - val_loss: 0.5276 - val_accuracy: 0.8602
# Epoch 53/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.7845 - accuracy: 0.6531 - val_loss: 0.5385 - val_accuracy: 0.8065
# Epoch 54/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.8374 - accuracy: 0.6450 - val_loss: 0.5062 - val_accuracy: 0.8710
# Epoch 55/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.8310 - accuracy: 0.6260 - val_loss: 0.4750 - val_accuracy: 0.8280
# Epoch 56/100
# 93/93 [==============================] - 9s 100ms/step - loss: 0.7838 - accuracy: 0.6423 - val_loss: 0.4886 - val_accuracy: 0.8280
# Epoch 57/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.7374 - accuracy: 0.7019 - val_loss: 0.4730 - val_accuracy: 0.8387
# Epoch 58/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.7802 - accuracy: 0.6802 - val_loss: 0.4625 - val_accuracy: 0.8280
# Epoch 59/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.7013 - accuracy: 0.6938 - val_loss: 0.4620 - val_accuracy: 0.8602
# Epoch 60/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.7395 - accuracy: 0.6992 - val_loss: 0.4395 - val_accuracy: 0.8387
# Epoch 61/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.7178 - accuracy: 0.7127 - val_loss: 0.4403 - val_accuracy: 0.8710
# Epoch 62/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.7297 - accuracy: 0.6911 - val_loss: 0.4429 - val_accuracy: 0.8495
# Epoch 63/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6878 - accuracy: 0.7100 - val_loss: 0.4166 - val_accuracy: 0.8710
# Epoch 64/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6654 - accuracy: 0.7209 - val_loss: 0.3807 - val_accuracy: 0.8817
# Epoch 65/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.7213 - accuracy: 0.6965 - val_loss: 0.3539 - val_accuracy: 0.8710
# Epoch 66/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.7069 - accuracy: 0.7019 - val_loss: 0.3575 - val_accuracy: 0.8710
# Epoch 67/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6674 - accuracy: 0.7236 - val_loss: 0.3604 - val_accuracy: 0.8710
# Epoch 68/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6127 - accuracy: 0.7371 - val_loss: 0.3515 - val_accuracy: 0.8817
# Epoch 69/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6493 - accuracy: 0.7561 - val_loss: 0.3379 - val_accuracy: 0.8925
# Epoch 70/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6956 - accuracy: 0.7236 - val_loss: 0.3279 - val_accuracy: 0.8710
# Epoch 71/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.6305 - accuracy: 0.7778 - val_loss: 0.3482 - val_accuracy: 0.8495
# Epoch 72/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.6218 - accuracy: 0.7425 - val_loss: 0.3384 - val_accuracy: 0.8602
# Epoch 73/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.5912 - accuracy: 0.7425 - val_loss: 0.3196 - val_accuracy: 0.8817
# Epoch 74/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6028 - accuracy: 0.7642 - val_loss: 0.3129 - val_accuracy: 0.8817
# Epoch 75/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6714 - accuracy: 0.7371 - val_loss: 0.2942 - val_accuracy: 0.8925
# Epoch 76/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.6202 - accuracy: 0.7398 - val_loss: 0.3089 - val_accuracy: 0.9032
# Epoch 77/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5930 - accuracy: 0.7696 - val_loss: 0.3143 - val_accuracy: 0.8925
# Epoch 78/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6647 - accuracy: 0.7236 - val_loss: 0.2910 - val_accuracy: 0.9140
# Epoch 79/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.6514 - accuracy: 0.7263 - val_loss: 0.2893 - val_accuracy: 0.8925
# Epoch 80/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5465 - accuracy: 0.7805 - val_loss: 0.2897 - val_accuracy: 0.8925
# Epoch 81/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5858 - accuracy: 0.7507 - val_loss: 0.3072 - val_accuracy: 0.8495
# Epoch 82/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5695 - accuracy: 0.7696 - val_loss: 0.2863 - val_accuracy: 0.8925
# Epoch 83/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5321 - accuracy: 0.7913 - val_loss: 0.2789 - val_accuracy: 0.8710
# Epoch 84/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.6158 - accuracy: 0.7534 - val_loss: 0.2693 - val_accuracy: 0.9140
# Epoch 85/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5545 - accuracy: 0.7913 - val_loss: 0.2743 - val_accuracy: 0.9140
# Epoch 86/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5174 - accuracy: 0.7913 - val_loss: 0.2545 - val_accuracy: 0.9247
# Epoch 87/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5521 - accuracy: 0.7669 - val_loss: 0.2782 - val_accuracy: 0.8710
# Epoch 88/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5078 - accuracy: 0.8266 - val_loss: 0.2737 - val_accuracy: 0.8602
# Epoch 89/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5180 - accuracy: 0.8022 - val_loss: 0.2489 - val_accuracy: 0.9032
# Epoch 90/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4996 - accuracy: 0.8103 - val_loss: 0.2557 - val_accuracy: 0.8925
# Epoch 91/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5880 - accuracy: 0.7832 - val_loss: 0.2725 - val_accuracy: 0.8817
# Epoch 92/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.5165 - accuracy: 0.7859 - val_loss: 0.2407 - val_accuracy: 0.8925
# Epoch 93/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5118 - accuracy: 0.7995 - val_loss: 0.2302 - val_accuracy: 0.9032
# Epoch 94/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5006 - accuracy: 0.8293 - val_loss: 0.2334 - val_accuracy: 0.8925
# Epoch 95/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4916 - accuracy: 0.8103 - val_loss: 0.2654 - val_accuracy: 0.8817
# Epoch 96/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5138 - accuracy: 0.8130 - val_loss: 0.2519 - val_accuracy: 0.8710
# Epoch 97/100
# 93/93 [==============================] - 9s 102ms/step - loss: 0.4864 - accuracy: 0.8076 - val_loss: 0.2203 - val_accuracy: 0.9032
# Epoch 98/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.5219 - accuracy: 0.8076 - val_loss: 0.2362 - val_accuracy: 0.9032
# Epoch 99/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4516 - accuracy: 0.8455 - val_loss: 0.2420 - val_accuracy: 0.9140
# Epoch 100/100
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4609 - accuracy: 0.8266 - val_loss: 0.2485 - val_accuracy: 0.8817

# %% [markdown]
# ## Evaluate Model

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# ----------------------------
# 1. Create a tf.data.Dataset for Evaluation
# ----------------------------
# Use a very small batch size during evaluation to avoid out-of-memory errors.
batch_size_eval = 1  # Adjust this value as necessary

# Wrap the test data in a tf.data.Dataset (this keeps only one batch in memory at a time)
test_dataset = tf.data.Dataset.from_tensor_slices(((features_test1, features_test2), labels_test1))
test_dataset = test_dataset.batch(batch_size_eval).prefetch(tf.data.AUTOTUNE)

# ----------------------------
# 2. Evaluate the Model on the Test Set
# ----------------------------
test_loss, test_accuracy = late_fusion_model.evaluate(test_dataset, verbose=1)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# ----------------------------
# 3. Generate Predictions and Plot the Confusion Matrix
# ----------------------------
# Predict on the test dataset
y_pred = late_fusion_model.predict(test_dataset)

# Convert predictions from softmax output to class indices
y_pred_labels = np.argmax(y_pred, axis=1)

# Convert true one-hot encoded labels to class indices
y_true = np.argmax(labels_test1, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Print a classification report
report = classification_report(y_true, y_pred_labels)
print("Classification Report:\n", report)

# ----------------------------
# 4. Plot Training Curves (Loss and Accuracy)
# ----------------------------
history_dict = history.history
epochs = range(1, len(history_dict['loss']) + 1)

plt.figure(figsize=(12, 5))

# Plot Loss Curves
plt.subplot(1, 2, 1)
plt.plot(epochs, history_dict['loss'], 'b-', label='Training Loss')
plt.plot(epochs, history_dict['val_loss'], 'r-', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(epochs, history_dict['accuracy'], 'b-', label='Training Accuracy')
plt.plot(epochs, history_dict['val_accuracy'], 'r-', label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 116/116 [==============================] - 5s 19ms/step - loss: 0.1556 - accuracy: 0.9483
# Test Loss: 0.1556
# Test Accuracy: 0.9483
# 116/116 [==============================] - 3s 16ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        31
#            1       0.92      1.00      0.96        44
#            2       1.00      0.90      0.95        41
#
#     accuracy                           0.95       116
#    macro avg       0.95      0.95      0.95       116
# weighted avg       0.95      0.95      0.95       116

# %% [markdown]
# ## Save Model

# %%
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

model_file_name = f'CNNGRU_model_Date_Time{current_date_time_string}_Loss_{test_loss}__Accuracy_{test_accuracy}.h5'

late_fusion_model.save(model_file_name)

# %% [markdown]
# ## Inference

# %%
import cv2
import numpy as np
import tensorflow as tf

# Define your class names
CLASSES_LIST = ['LumbarSideBends', 'QuadrupedThoracicRotation', 'SupineNeckLift']

# ----------------------------
# Optical Flow Functions (Lucas-Kanade)
# ----------------------------
def compute_optical_flow(prev_frame, next_frame):
    """
    Compute optical flow using the Lucas-Kanade method between two frames.
    
    Returns:
        good_old: Array of points from the previous frame.
        good_new: Array of corresponding points from the next frame.
    """
    # Convert frames to grayscale
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

    # Parameters for Lucas-Kanade optical flow
    lk_params = dict(winSize=(21, 21),
                     maxLevel=3,
                     criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 30, 0.01))

    # Parameters for Shi-Tomasi corner detection (good features to track)
    feature_params = dict(maxCorners=3000, qualityLevel=0.01, minDistance=0.1)
    
    # Detect features in the previous frame
    p0 = cv2.goodFeaturesToTrack(prev_gray, mask=None, **feature_params)
    if p0 is None:
        return [], []

    # Calculate optical flow (find corresponding points in the next frame)
    p1, st, err = cv2.calcOpticalFlowPyrLK(prev_gray, next_gray, p0, None, **lk_params)

    # Ensure valid output and select good points based on the status array
    if p1 is not None and st is not None:
        st = st.flatten()
        good_old = p0[st == 1]
        good_new = p1[st == 1]
    else:
        good_old, good_new = [], []

    return good_old, good_new

def create_mei_mhi(flow, shape, tau=10):
    """
    Create Motion Energy Image (MEI) and Motion History Image (MHI) from optical flow vectors.
    
    Args:
        flow: Tuple containing (good_old, good_new) points.
        shape: Tuple defining the output image size (height, width).
        tau: Time constant for motion decay in the MHI.
        
    Returns:
        mei: The Motion Energy Image (binary representation of motion).
        mhi: The Motion History Image (captures motion intensity with decay).
    """
    # Initialize MEI and MHI as zero arrays
    mei = np.zeros(shape, dtype=np.float32)
    mhi = np.zeros(shape, dtype=np.float32)

    # Iterate over each pair of corresponding points to draw motion vectors
    for (new, old) in zip(flow[1], flow[0]):
        x1, y1 = new.ravel()
        x2, y2 = old.ravel()
        
        # Draw motion on MEI (binary)
        cv2.line(mei, (int(x1), int(y1)), (int(x2), int(y2)), 255, 2)
        
        # Draw motion on MHI (with intensity)
        cv2.line(mhi, (int(x1), int(y1)), (int(x2), int(y2)), 255, 2)

    # Decay MHI over time
    mhi[mhi > 0] -= 255 / tau  
    mhi[mhi < 0] = 0

    return mei, mhi

# ----------------------------
# Define Optical Flow Sequence Using Lucas-Kanade
# ----------------------------
def compute_optical_flow_sequence_lk(frames, target_size=(240, 320), tau=10):
    """
    For a list of frames, resize them to target_size (which is in (width, height) order),
    compute Lucas-Kanade optical flow between consecutive frames, and use create_mei_mhi
    to obtain a Motion Energy Image (MEI). The MEI is normalized to [0,1].
    
    Returns a numpy array of shape (num_frames, target_height, target_width, 1).
    """
    # First, resize frames for optical flow computation.
    # target_size is (width, height); output images will have shape (height, width).
    resized_frames = []
    for frame in frames:
        resized = cv2.resize(frame, target_size)
        resized_frames.append(resized)
    
    flow_sequence = []
    for i in range(len(resized_frames) - 1):
        prev_frame = resized_frames[i]
        next_frame = resized_frames[i + 1]
        good_old, good_new = compute_optical_flow(prev_frame, next_frame)
        if len(good_old) == 0 or len(good_new) == 0:
            # If no flow is detected, use a zero image
            mei = np.zeros((target_size[1], target_size[0]), dtype=np.float32)
        else:
            mei, _ = create_mei_mhi((good_old, good_new), (target_size[1], target_size[0]), tau=tau)
            # Normalize the MEI from 0 to 1
            mei = mei / 255.0
        # Expand dims to add the channel dimension (resulting shape: (height, width, 1))
        mei = np.expand_dims(mei, axis=-1)
        flow_sequence.append(mei.astype(np.float32))
    
    # Optical flow computed from N frames gives N-1 flow images.
    # Pad the sequence with a zero frame to match the number of frames.
    desired_length = len(frames)
    while len(flow_sequence) < desired_length:
        zero_frame = np.zeros((target_size[1], target_size[0], 1), dtype=np.float32)
        flow_sequence.append(zero_frame)
    
    return np.array(flow_sequence)

def preprocess_rgb_frames(frames, target_size=(IMAGE_HEIGHT, IMAGE_WIDTH)):
    """
    Preprocess RGB frames:
    - Resize to target_size
    - Convert BGR to RGB
    - Normalize to [0, 1]
    """
    rgb_frames = []
    for frame in frames:
        resized = cv2.resize(frame, target_size)
        rgb = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)
        rgb = rgb.astype(np.float32) / 255.0
        rgb_frames.append(rgb)
    return np.array(rgb_frames)

def sample_frames_from_video(video_path, num_frames):
    """
    Samples frames uniformly from the video.
    """
    cap = cv2.VideoCapture(video_path)
    frames = []
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames < num_frames:
        print("Warning: Video has fewer frames than requested; using available frames.")
        num_frames = total_frames
    indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    current_index = 0
    ret = True
    while ret and current_index < total_frames:
        ret, frame = cap.read()
        if current_index in indices:
            frames.append(frame)
        current_index += 1
    cap.release()
    return frames

def ensure_video_resolution(frames, target_size=(320, 240)):
    """
    Ensures all frames are at the target resolution.
    """
    resized_frames = []
    for frame in frames:
        resized_frame = cv2.resize(frame, target_size)
        resized_frames.append(resized_frame)
    return resized_frames

def run_inference_on_video(video_path, model, num_frames=30):
    """
    Process video and run inference using Farneback optical flow.
    """
    # Sample frames from the video
    frames = sample_frames_from_video(video_path, num_frames)
    if len(frames) < num_frames:
        print("Error: Not enough frames in the video for inference.")
        return None, None

    # Ensure all frames are resized to 320x240 resolution
    frames = ensure_video_resolution(frames, target_size=(320, 240))
    
    # Preprocess frames for the RGB stream
    rgb_sequence = preprocess_rgb_frames(frames, target_size=(96, 96))
    
    # Preprocess frames for the optical flow stream using Farneback
    flow_sequence = compute_optical_flow_sequence_lk(frames, target_size=(OF_IMAGE_HEIGHT, OF_IMAGE_WIDTH))
    
    # Add batch dimension
    rgb_input = np.expand_dims(rgb_sequence, axis=0)
    flow_input = np.expand_dims(flow_sequence, axis=0)
    
    # Run model inference
    predictions = model.predict([rgb_input, flow_input])
    pred_class = np.argmax(predictions, axis=1)[0]
    return pred_class, predictions

if __name__ == "__main__":
    video_path = input("Enter the path to the video file for inference: ").strip()
    
    # Load the model
    model_path = r"D:\MAPUA\CNN_GRU_VarietyofOF\CNNGRU_model_Date_Time2025_02_24__02_06_20_Loss_0.15555697679519653__Accuracy_0.9482758641242981.h5"
    late_fusion_model = tf.keras.models.load_model(model_path)
    print(f"Loaded model from {model_path}")
    
    # Run inference
    predicted_class, probs = run_inference_on_video(video_path, late_fusion_model, num_frames=30)
    
    if predicted_class is not None:
        predicted_class_name = CLASSES_LIST[predicted_class]
        confidence_percentage = probs[0][predicted_class] * 100
        print(f"Predicted Class: {predicted_class_name} with {confidence_percentage:.2f}% confidence.")
# Out:
# Loaded model from D:\MAPUA\CNN_GRU_VarietyofOF\CNNGRU_model_Date_Time2025_02_24__02_06_20_Loss_0.15555697679519653__Accuracy_0.9482758641242981.h5
# 1/1 [==============================] - 2s 2s/step
# Predicted Class: SupineNeckLift with 99.46% confidence.
